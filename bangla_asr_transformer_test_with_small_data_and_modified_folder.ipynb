# %% [markdown]
# <a href="https://colab.research.google.com/github/Taleb10/BangalASR/blob/main/bangla_asr_transformer_test_with_small_data_and_modified_folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Original repository - https://github.com/menon92/BangalASR
# !sudo apt install -qq sox -y
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 20 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 8.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %%
import os
import random
from glob import glob
from tqdm import tqdm
from multiprocessing import Pool

import librosa

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


print("TensorFlow:", tf.__version__)
# Set seed for experiment reproducibility
seed = 777
tf.random.set_seed(seed)
# Out:
# TensorFlow: 2.9.2

# %%
# !wget -q https://www.openslr.org/resources/53/asr_bengali_0.zip
# !wget -q https://www.openslr.org/resources/53/asr_bengali_1.zip
# !wget -q https://www.openslr.org/resources/53/asr_bengali_2.zip
# !wget -q https://www.openslr.org/resources/53/asr_bengali_3.zip
# !wget -q https://www.openslr.org/resources/53/asr_bengali_4.zip

# %%
# !unzip -o -q asr_bengali_0.zip
# !unzip -o -q asr_bengali_1.zip
# !unzip -o asr_bengali_2.zip
# !unzip -o -q asr_bengali_3.zip
# !unzip -o asr_bengali_4.zip

# %%
utt_path = 'asr_bengali/utt_spk_text.tsv'
flac_audio_dir = 'asr_bengali/data'

max_target_len = 30 # 100 # 200  # all transcripts in out data are < 200 characters

# %%
import pandas as pd
data=pd.read_csv('asr_bengali/utt_spk_text.tsv',sep='\t')
data.head(10)
# Out:
#    070078fb60  976b1        তেঁতুলিয়ার ভজনপুর গ্রামে
# 0  070091fd89  f83df           জবাবদিহিতায় আনার জন্য
# 1  070a2946a9  9813c       বিষয়টি পুলিশ কে জানানো হয়
# 2  071d32bd73  7ec1c       ১৯৮৭ সালের বিশ ফেব্রুয়ারি
# 3  072f9bb48f  e43d4     অফিস ছুটির সর্বশেষ ভার্সনটি
# 4  073598e69d  5639c        এক শূন্য গোলে পরাজিত করে
# 5  0750033e3e  321b6  সবচেয়ে দরিদ্র এলাকা গুলোর একটি
# 6  0772cc6e7c  a46e2         আকাশের দিকেই ছুড়তে থাকে
# 7  075a697ef7  e00db       শিশু শ্রমিক রয়েছে দেশটিতে
# 8  07738a801d  4c555      চাঁদনী রাতের ভালোবাসার ফটো

# %%
# !rm -rf /content/asr_bengali/data/00
# !rm -rf /content/asr_bengali/data/0a
# !rm -rf /content/asr_bengali/data/03
# !rmd -rf /content/asr_bengali/data/0a
# !rm -rf /content/asr_bengali/data/0b
# !rm -rf /content/asr_bengali/data/0c
# !rm -rf /content/asr_bengali/data/0d
# !rm -rf /content/asr_bengali/data/0e
# !rm -rf /content/asr_bengali/data/0f

# %% [markdown]
# ## Peak small data from large datasets

# %%
FILTER_CHARS = [
    '"', '%', "'", ',', '-', '.', '/', '\x93', '\x94', '\u200c', '\u200d', '‘', 
    '’', '“', '”', '…', '!', ':', ';', '?', 'œ', '।', '–'
]

ENGLISH = set([
    '0', '1', '2', '3', '4', '5', 'B', 'L', 'T', 'a', 'b', 'c', 'd', 'e', 'f', 
    'g', 'h', 'i', 'l', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'w', 'x', 'z',
])


def clean(text):
    '''Clean text'''
    for c in FILTER_CHARS:
        if c in text:
            text = text.replace(c, '')
    return text


def is_contrain_english_chars(text):
    if ENGLISH.intersection(set(text)):
        return True
    return False 

def convert_flac_to_wav(f):
    cmd = f"sox {f} {f.split('.')[0] + '.wav'}"
    os.system(cmd)

def get_data(utt_path, flac_audio_dir):
    '''Get data from utt, flac audio dir
    '''
# modified from 5000 to 10 here [T] and commented the multiply option  _take*2

    _take = 10
    flac_audio_files = glob(flac_audio_dir + '/*.flac')
    # [:_take*2]

    print(f"Converting flac to wav")
    with Pool(os.cpu_count()) as p:
      r = list(tqdm(p.imap(
          convert_flac_to_wav, flac_audio_files), total=len(flac_audio_files)))
    print('done')
    
    flac_list = [
        os.path.splitext(os.path.basename(_file))[0] 
        for _file in flac_audio_files
    ]
    flac_set = set(flac_list)

    data = []
    unique_chars = set()
    max_text_len = 0
    max_text = ''
    en_bn_mixed = 0
    takes = 0
    audio_duration = 0
    unique_words = set()
    with open(utt_path, 'r') as fp:
        lines = fp.readlines()
        for line in tqdm(lines, total=len(lines)):
            line = line.strip(' \n')
            line = line.split('\t')
            file_name, text= line[0], line[2]
    
            if takes >= _take:
                break

            if file_name in flac_set:
                text = clean(text)
                # skip text which has > max_target_len chars
                if len(text) > max_target_len:
                    continue
                
                # skip english text
                if is_contrain_english_chars(text):
                    en_bn_mixed += 1
                    continue
                
                file_abs_path = flac_audio_files[flac_list.index(file_name)].split('.')[0] + '.wav'
# ==================

                # file_abs_path = '/content/asr-bengali/data/'
# ==============
                data.append({'audio': file_abs_path, 'text': text})
                duration = librosa.get_duration(filename=file_abs_path)
                audio_duration += duration
                # create unique chars set
                for c in text:
                    unique_chars.add(c)
                
                words = text.split()
                for w in words:
                    unique_words.add(w)
                
                # find max text sequence lenght, text
                text_len = len(text)
                if max_text_len < text_len:
                    max_text_len = text_len
                    max_text = text
                
                takes += 1
                
    unique_chars = sorted(unique_chars)

    print(f'flac audio files: {len(flac_audio_files)}')
    print(f'flac_dic         : {len(flac_set)}')
    print(f'utt entry       : {len(lines)}')
    print(f'unique chars  : {len(unique_chars)}')
    print(f'data             : {len(data)}')
    print(f"max text length : {max_text_len}")
    print(f'max text          : {max_text}')
    print(f'en bn mixed     : {en_bn_mixed}')
    print(f"Total unique words: {len(unique_words)}")
    print(f"audio duration: {audio_duration / 3600:.3f} hr")
 
    return data, unique_chars

# %%
data, unique_chars = get_data(utt_path, flac_audio_dir)
print('chars:', unique_chars)
# Out:
# Converting flac to wav
# 100%|██████████| 10/10 [00:00<00:00, 14.06it/s]
# done
# 100%|██████████| 10/10 [00:00<00:00, 7594.25it/s]
# flac audio files: 10
# flac_dic         : 10
# utt entry       : 10
# unique chars  : 42
# data             : 10
# max text length : 30
# max text          : সবচেয়ে দরিদ্র এলাকা গুলোর একটি
# en bn mixed     : 0
# Total unique words: 41
# audio duration: 0.011 hr
# chars: [' ', 'ঁ', 'অ', 'আ', 'ই', 'এ', 'ক', 'গ', 'চ', 'ছ', 'জ', 'ট', 'ত', 'থ', 'দ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', 'া', 'ি', 'ী', 'ু', 'ূ', 'ে', 'ো', '্', 'ড়', 'য়', '১', '৭', '৮', '৯']

# %% [markdown]
# ## Define network

# %%
class TokenEmbedding(layers.Layer):
    def __init__(self, num_vocab=1000, maxlen=100, num_hid=64):
        super().__init__()
        self.emb = tf.keras.layers.Embedding(num_vocab, num_hid)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        x = self.emb(x)
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        return x + positions


class SpeechFeatureEmbedding(layers.Layer):
    def __init__(self, num_hid=64, maxlen=100):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv2 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv3 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        return self.conv3(x)


class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, dropout_rate=0.1):
        super().__init__()
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = layers.LayerNormalization(epsilon=1e-6)
        self.self_att = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.enc_att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.self_dropout = layers.Dropout(0.5)
        self.enc_dropout = layers.Dropout(0.1)
        self.ffn_dropout = layers.Dropout(0.1)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )

    def causal_attention_mask(self, batch_size, n_dest, n_src, dtype):
        """Masks the upper half of the dot product matrix in self attention.

        This prevents flow of information from future tokens to current token.
        1's in the lower triangle, counting from the lower right corner.
        """
        i = tf.range(n_dest)[:, None]
        j = tf.range(n_src)
        m = i >= j - n_src + n_dest
        mask = tf.cast(m, dtype)
        mask = tf.reshape(mask, [1, n_dest, n_src])
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
        )
        return tf.tile(mask, mult)

    def call(self, enc_out, target):
        input_shape = tf.shape(target)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = self.causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        target_att = self.self_att(target, target, attention_mask=causal_mask)
        target_norm = self.layernorm1(target + self.self_dropout(target_att))
        enc_out = self.enc_att(target_norm, enc_out)
        enc_out_norm = self.layernorm2(self.enc_dropout(enc_out) + target_norm)
        ffn_out = self.ffn(enc_out_norm)
        ffn_out_norm = self.layernorm3(enc_out_norm + self.ffn_dropout(ffn_out))
        return ffn_out_norm

    
class Transformer(keras.Model):
    def __init__(
        self,
        num_hid=64,
        num_head=2,
        num_feed_forward=128,
        source_maxlen=100,
        target_maxlen=100,
        num_layers_enc=4,
        num_layers_dec=1,
        num_classes=10,
    ):
        super().__init__()
        self.loss_metric = keras.metrics.Mean(name="loss")
        self.num_layers_enc = num_layers_enc
        self.num_layers_dec = num_layers_dec
        self.target_maxlen = target_maxlen
        self.num_classes = num_classes

        self.enc_input = SpeechFeatureEmbedding(num_hid=num_hid, maxlen=source_maxlen)
        self.dec_input = TokenEmbedding(
            num_vocab=num_classes, maxlen=target_maxlen, num_hid=num_hid
        )

        self.encoder = keras.Sequential(
            [self.enc_input]
            + [
                TransformerEncoder(num_hid, num_head, num_feed_forward)
                for _ in range(num_layers_enc)
            ]
        )

        for i in range(num_layers_dec):
            setattr(
                self,
                f"dec_layer_{i}",
                TransformerDecoder(num_hid, num_head, num_feed_forward),
            )

        self.classifier = layers.Dense(num_classes, activation='softmax')

    def decode(self, enc_out, target):
        y = self.dec_input(target)
        for i in range(self.num_layers_dec):
            y = getattr(self, f"dec_layer_{i}")(enc_out, y)
        return y

    def call(self, inputs):
        source = inputs[0]
        target = inputs[1]
        x = self.encoder(source)
        y = self.decode(x, target)
        return self.classifier(y)

    @property
    def metrics(self):
        return [self.loss_metric]

    @tf.function
    def train_step(self, batch):
        """Processes one batch inside model.fit()."""
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        with tf.GradientTape() as tape:
            preds = self([source, dec_input])
            one_hot = tf.one_hot(dec_target, depth=self.num_classes)
            mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
            loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.loss_metric.update_state(loss)
        return {"loss": self.loss_metric.result()}

    def test_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        preds = self([source, dec_input])
        # print('test preds', preds.numpy)
        one_hot = tf.one_hot(dec_target, depth=self.num_classes)
        mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
        loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        self.loss_metric.update_state(loss)
        return {"loss": self.loss_metric.result()}

    def generate(self, source, target_start_token_idx):
        """Performs inference over one batch of inputs using greedy decoding."""
        bs = tf.shape(source)[0]
        enc = self.encoder(source)
        dec_input = tf.ones((bs, 1), dtype=tf.int32) * target_start_token_idx
        dec_logits = []
        for i in range(self.target_maxlen - 1):
            dec_out = self.decode(enc, dec_input)
            logits = self.classifier(dec_out)
            logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
            last_logit = tf.expand_dims(logits[:, -1], axis=-1)
            dec_logits.append(last_logit)
            dec_input = tf.concat([dec_input, last_logit], axis=-1)
        return dec_input

# %% [markdown]
# ## Define schedulare

# %%
class DisplayOutputs(keras.callbacks.Callback):
    def __init__(
        self, batch, idx_to_token, target_start_token_idx=27, target_end_token_idx=28
    ):
        """Displays a batch of outputs after every epoch

        Args:
            batch: A test batch containing the keys "source" and "target"
            idx_to_token: A List containing the vocabulary tokens corresponding to their indices
            target_start_token_idx: A start token index in the target vocabulary
            target_end_token_idx: An end token index in the target vocabulary
        """
        self.batch = batch
        self.target_start_token_idx = target_start_token_idx
        self.target_end_token_idx = target_end_token_idx
        self.idx_to_char = idx_to_token

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 20 != 0:
            return
        self.batch = batch = next(iter(val_ds))
        source = self.batch["source"]
        target = self.batch["target"].numpy()
        bs = tf.shape(source)[0]
        preds = self.model.generate(source, self.target_start_token_idx)
        preds = preds.numpy()
        for i in range(bs):
            target_text = "".join([self.idx_to_char[_] for _ in target[i, :]])
            prediction = ""
            # print("preds[i, :]", preds[i, :])
            for idx in preds[i, :]:
                prediction += self.idx_to_char[idx]
                if idx == self.target_end_token_idx:
                    break
            print(f"target:     {target_text.replace('-','')}")
            print(f"prediction: {prediction}")


class CustomSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self,
        init_lr=0.00001,
        lr_after_warmup=0.001,
        final_lr=0.00001,
        warmup_epochs=15,
        decay_epochs=85,
        steps_per_epoch=203,
    ):
        super().__init__()
        self.init_lr = init_lr
        self.lr_after_warmup = lr_after_warmup
        self.final_lr = final_lr
        self.warmup_epochs = warmup_epochs
        self.decay_epochs = decay_epochs
        self.steps_per_epoch = steps_per_epoch

    def calculate_lr(self, epoch):
        """ linear warm up - linear decay """
        warmup_lr = (
            self.init_lr
            + ((self.lr_after_warmup - self.init_lr) / (self.warmup_epochs - 1)) * epoch
        )
        decay_lr = tf.math.maximum(
            self.final_lr,
            self.lr_after_warmup
            - (epoch - self.warmup_epochs)
            * (self.lr_after_warmup - self.final_lr)
            / (self.decay_epochs),
        )
        lr =  tf.math.minimum(warmup_lr, decay_lr)
        return lr

    def __call__(self, step):
        epoch = step // self.steps_per_epoch
        return self.calculate_lr(epoch)

# %% [markdown]
# ## Define loader

# %%
class VectorizeChar:
    def __init__(self, max_len=50):
        self.vocab = (
            ["-", "#", "<", ">"]
            + list(unique_chars)
            # + [chr(i + 96) for i in range(1, 27)]
            # + [" ", ".", ",", "?"]
        )
        self.max_len = max_len
        self.char_to_idx = {}
        for i, ch in enumerate(self.vocab):
            self.char_to_idx[ch] = i

    def __call__(self, text):
        # text = text.lower()
        text = text[: self.max_len - 2]
        text = "<" + text + ">"
        pad_len = self.max_len - len(text)
        return [self.char_to_idx.get(ch, 1) for ch in text] + [0] * pad_len

    def get_vocabulary(self):
        return self.vocab


# data = get_data(wavs, id_to_text, max_target_len)
vectorizer = VectorizeChar(max_target_len)
print("vocab size", len(vectorizer.get_vocabulary()))


def create_text_ds(data):
    texts = [_["text"] for _ in data]
    text_ds = [vectorizer(t) for t in texts]
    text_ds = tf.data.Dataset.from_tensor_slices(text_ds)
    return text_ds


def path_to_audio(path):
    # spectrogram using stft
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1)    
    # audio = tf.cast(tfio.audio.decode_flac(audio, dtype=tf.int16), tf.float32)
    audio = tf.squeeze(audio, axis=-1)
    stfts = tf.signal.stft(audio, frame_length=200, frame_step=80, fft_length=256)
    x = tf.math.pow(tf.abs(stfts), 0.5)
    audio_len = tf.shape(x)[0]
    # padding to 10 seconds
    pad_len = 1700 # 2754
    paddings = tf.constant([[0, pad_len], [0, 0]])
#     print('paddings shape:', tf.shape(paddings))
    x = tf.pad(x, paddings, "CONSTANT")[:pad_len, :]
#     print('final audio len:', tf.shape(x))
    return x


def create_audio_ds(data):
    flist = [_["audio"] for _ in data]
    audio_ds = tf.data.Dataset.from_tensor_slices(flist)
    audio_ds = audio_ds.map(
        path_to_audio, num_parallel_calls=tf.data.experimental.AUTOTUNE
    )
    return audio_ds

# @tf.function
def create_tf_dataset(data, bs=4, val_data=False):
    audio_ds = create_audio_ds(data)
    text_ds = create_text_ds(data)
    ds = tf.data.Dataset.zip((audio_ds, text_ds))
    ds = ds.map(lambda x, y: {"source": x, "target": y})
    # cashe data to RAM 
    ds = ds.cache()
    # do shuffle
    ds = ds.shuffle(1000)
    ds = ds.batch(bs)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

data = data

# [T] modifie from 0.99 to 0.50
split = int(len(data) * 0.50)   
train_data = data # data[:split]
test_data =  data[split:]
# ds = create_tf_dataset(train_data, bs=400)
ds = create_tf_dataset(train_data, bs=64)
val_ds = create_tf_dataset(test_data, bs=64)
# Out:
# vocab size 46

# %% [markdown]
# ### **Upper one edited [T]**

# %% [markdown]
# ## Visualize data

# %%
print(f"Total test data: {len(test_data)}")
# Out:
# Total test data: 5

# %%
import IPython
import random
for i in range(5):
    idx = random.randint(0,len(train_data))
    item = train_data[idx]
    print(item["text"])
    IPython.display.display(IPython.display.Audio(item["audio"]))
# Out:
# আকাশের দিকেই ছুড়তে থাকে
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# শিশু শ্রমিক রয়েছে দেশটিতে
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# এক শূন্য গোলে পরাজিত করে
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ১৯৮৭ সালের বিশ ফেব্রুয়ারি
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# আকাশের দিকেই ছুড়তে থাকে
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
batch = next(iter(val_ds))

# The vocabulary to convert predicted indices into characters
idx_to_char = vectorizer.get_vocabulary()
display_cb = DisplayOutputs(
    batch, idx_to_char, target_start_token_idx=2, target_end_token_idx=3
)  # set the arguments as per vocabulary index for '<' and '>'

model = Transformer(
    num_hid=128,
    num_head=2,
    num_feed_forward=256,
    target_maxlen=max_target_len,
    num_layers_enc=2,
    num_layers_dec=1,
    num_classes=len(vectorizer.get_vocabulary()) # 75 # 48 # 67 # 108,
)
loss_fn = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, label_smoothing=0.1,
)

learning_rate = CustomSchedule(
    init_lr=0.00001,
    lr_after_warmup=0.001,
    final_lr=0.00001,
    warmup_epochs=15,
    decay_epochs=85,
    steps_per_epoch=len(ds),
)
optimizer = keras.optimizers.Adam(learning_rate)
# optimizer = keras.optimizers.Adam()
# optimizer = keras.optimizers.Adam(lr=0.00005)

# model.compile(optimizer=optimizer, loss=loss_fn)
model.compile(optimizer='adam', loss=loss_fn)
# model.load_weights('/content/gdrive/MyDrive/bangla-ai/models/bnasr-57')
# latest = tf.train.latest_checkpoint('/content/drive/MyDrive/bangla-ai/models/08-04-2021_ID_03')
# model.load_weights(latest)

# %%
if not os.path.exists("asr-checkpoint"):
    os.makedirs("asr-checkpoint")

# checkpoint_path = 'asr-checkpoint/bnasr-{epoch:02d}-{val_loss:0.6f}'
checkpoint_path = '/content/cp.ckpt'
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
    # save_freq=1,
    verbose=0
)

print("tf.executing_eagerly():", tf.executing_eagerly())

# optimizer = keras.optimizers.Adam(lr=0.0001)
# model.compile(optimizer=optimizer, loss=loss_fn)


history = model.fit(
    ds, 
    validation_data=val_ds, 
    callbacks=[display_cb,cp_callback],
    initial_epoch=0,
    epochs=500
)
# Out:
# tf.executing_eagerly(): True
# Epoch 1/500
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 1/1 [==============================] - ETA: 0s - loss: 4.0352target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: < েসুে ে ন  য ে ন ল্া ন্ া>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: < েসুে ে ন  য ে ন ল্া ন্ া>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: < েসুে ে ন  য ে ন ল্ে ন্ া>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: < েসুে ে ন  য ে ন ল্া ন্ া>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: < েসুে ে ন  য ে ন ল্া ন্ া>
# 1/1 [==============================] - 6s 6s/step - loss: 4.0352 - val_loss: 3.4619
# Epoch 2/500
# 1/1 [==============================] - 0s 191ms/step - loss: 3.4204 - val_loss: 3.1063
# Epoch 3/500
# 1/1 [==============================] - 0s 206ms/step - loss: 3.0721 - val_loss: 2.8355
# Epoch 4/500
# 1/1 [==============================] - 0s 193ms/step - loss: 2.8170 - val_loss: 2.6237
# Epoch 5/500
# 1/1 [==============================] - 0s 185ms/step - loss: 2.6071 - val_loss: 2.4495
# Epoch 6/500
# 1/1 [==============================] - 0s 184ms/step - loss: 2.4305 - val_loss: 2.2868
# Epoch 7/500
# 1/1 [==============================] - 0s 187ms/step - loss: 2.2678 - val_loss: 2.1262
# Epoch 8/500
# 1/1 [==============================] - 0s 194ms/step - loss: 2.1093 - val_loss: 1.9827
# Epoch 9/500
# 1/1 [==============================] - 0s 188ms/step - loss: 1.9664 - val_loss: 1.8585
# Epoch 10/500
# 1/1 [==============================] - 0s 188ms/step - loss: 1.8433 - val_loss: 1.7483
# Epoch 11/500
# 1/1 [==============================] - 0s 183ms/step - loss: 1.7362 - val_loss: 1.6491
# Epoch 12/500
# 1/1 [==============================] - 0s 203ms/step - loss: 1.6401 - val_loss: 1.5651
# Epoch 13/500
# 1/1 [==============================] - 0s 180ms/step - loss: 1.5572 - val_loss: 1.4951
# Epoch 14/500
# 1/1 [==============================] - 0s 184ms/step - loss: 1.4839 - val_loss: 1.4367
# Epoch 15/500
# 1/1 [==============================] - 0s 195ms/step - loss: 1.4190 - val_loss: 1.3858
# Epoch 16/500
# 1/1 [==============================] - 0s 196ms/step - loss: 1.3608 - val_loss: 1.3401
# Epoch 17/500
# 1/1 [==============================] - 0s 188ms/step - loss: 1.3100 - val_loss: 1.2969
# Epoch 18/500
# 1/1 [==============================] - 0s 187ms/step - loss: 1.2651 - val_loss: 1.2540
# Epoch 19/500
# 1/1 [==============================] - 0s 205ms/step - loss: 1.2235 - val_loss: 1.2147
# Epoch 20/500
# 1/1 [==============================] - 0s 193ms/step - loss: 1.1865 - val_loss: 1.1822
# Epoch 21/500
# 1/1 [==============================] - ETA: 0s - loss: 1.1552target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <সবচেয়ে দরিদ্র এলোবা গুলোর এক>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <সবচেয়ে দরিদ্র এলোবা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# 1/1 [==============================] - 1s 777ms/step - loss: 1.1552 - val_loss: 1.1554
# Epoch 22/500
# 1/1 [==============================] - 0s 190ms/step - loss: 1.1277 - val_loss: 1.1331
# Epoch 23/500
# 1/1 [==============================] - 0s 186ms/step - loss: 1.1026 - val_loss: 1.1135
# Epoch 24/500
# 1/1 [==============================] - 0s 188ms/step - loss: 1.0791 - val_loss: 1.0955
# Epoch 25/500
# 1/1 [==============================] - 0s 190ms/step - loss: 1.0574 - val_loss: 1.0779
# Epoch 26/500
# 1/1 [==============================] - 0s 196ms/step - loss: 1.0376 - val_loss: 1.0596
# Epoch 27/500
# 1/1 [==============================] - 0s 186ms/step - loss: 1.0198 - val_loss: 1.0400
# Epoch 28/500
# 1/1 [==============================] - 0s 185ms/step - loss: 1.0032 - val_loss: 1.0196
# Epoch 29/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.9874 - val_loss: 1.0004
# Epoch 30/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.9725 - val_loss: 0.9836
# Epoch 31/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.9586 - val_loss: 0.9690
# Epoch 32/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.9453 - val_loss: 0.9565
# Epoch 33/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.9326 - val_loss: 0.9454
# Epoch 34/500
# 1/1 [==============================] - 0s 210ms/step - loss: 0.9207 - val_loss: 0.9345
# Epoch 35/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.9096 - val_loss: 0.9225
# Epoch 36/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.8989 - val_loss: 0.9095
# Epoch 37/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.8884 - val_loss: 0.8965
# Epoch 38/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.8783 - val_loss: 0.8855
# Epoch 39/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.8687 - val_loss: 0.8753
# Epoch 40/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.8600 - val_loss: 0.8709
# Epoch 41/500
# 1/1 [==============================] - ETA: 0s - loss: 0.8540target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <তেঁতুলিয়ার ভজনপুর গ্রামে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# 1/1 [==============================] - 1s 808ms/step - loss: 0.8540 - val_loss: 0.8595
# Epoch 42/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.8467 - val_loss: 0.8487
# Epoch 43/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.8347 - val_loss: 0.8443
# Epoch 44/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.8296 - val_loss: 0.8334
# Epoch 45/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.8233 - val_loss: 0.8249
# Epoch 46/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.8136 - val_loss: 0.8204
# Epoch 47/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.8090 - val_loss: 0.8109
# Epoch 48/500
# 1/1 [==============================] - 0s 182ms/step - loss: 0.8037 - val_loss: 0.8048
# Epoch 49/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.7954 - val_loss: 0.8019
# Epoch 50/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.7915 - val_loss: 0.7940
# Epoch 51/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.7874 - val_loss: 0.7912
# Epoch 52/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.7810 - val_loss: 0.7857
# Epoch 53/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.7760 - val_loss: 0.7797
# Epoch 54/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.7733 - val_loss: 0.7775
# Epoch 55/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.7684 - val_loss: 0.7712
# Epoch 56/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.7634 - val_loss: 0.7666
# Epoch 57/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7615 - val_loss: 0.7704
# Epoch 58/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.7608 - val_loss: 0.7621
# Epoch 59/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.7560 - val_loss: 0.7595
# Epoch 60/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7511 - val_loss: 0.7622
# Epoch 61/500
# 1/1 [==============================] - ETA: 0s - loss: 0.7515target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# 1/1 [==============================] - 1s 813ms/step - loss: 0.7515 - val_loss: 0.7533
# Epoch 62/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7494 - val_loss: 0.7543
# Epoch 63/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7438 - val_loss: 0.7545
# Epoch 64/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.7431 - val_loss: 0.7490
# Epoch 65/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.7403 - val_loss: 0.7461
# Epoch 66/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7376 - val_loss: 0.7464
# Epoch 67/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.7364 - val_loss: 0.7407
# Epoch 68/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.7330 - val_loss: 0.7385
# Epoch 69/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7307 - val_loss: 0.7402
# Epoch 70/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.7308 - val_loss: 0.7360
# Epoch 71/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7300 - val_loss: 0.7387
# Epoch 72/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.7270 - val_loss: 0.7356
# Epoch 73/500
# 1/1 [==============================] - 0s 215ms/step - loss: 0.7235 - val_loss: 0.7330
# Epoch 74/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.7240 - val_loss: 0.7351
# Epoch 75/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.7228 - val_loss: 0.7288
# Epoch 76/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.7201 - val_loss: 0.7276
# Epoch 77/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.7170 - val_loss: 0.7294
# Epoch 78/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.7179 - val_loss: 0.7252
# Epoch 79/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.7186 - val_loss: 0.7258
# Epoch 80/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.7137 - val_loss: 0.7253
# Epoch 81/500
# 1/1 [==============================] - ETA: 0s - loss: 0.7125target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <তেঁতুলিয়ার ভজনপুর গ্রামে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# 1/1 [==============================] - 1s 790ms/step - loss: 0.7125 - val_loss: 0.7226
# Epoch 82/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.7140 - val_loss: 0.7224
# Epoch 83/500
# 1/1 [==============================] - 0s 211ms/step - loss: 0.7092 - val_loss: 0.7210
# Epoch 84/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.7084 - val_loss: 0.7183
# Epoch 85/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.7112 - val_loss: 0.7171
# Epoch 86/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7050 - val_loss: 0.7207
# Epoch 87/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.7085 - val_loss: 0.7170
# Epoch 88/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.7136 - val_loss: 0.7154
# Epoch 89/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7027 - val_loss: 0.7230
# Epoch 90/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7111 - val_loss: 0.7179
# Epoch 91/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.7206 - val_loss: 0.7142
# Epoch 92/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7012 - val_loss: 0.7194
# Epoch 93/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.7089 - val_loss: 0.7134
# Epoch 94/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.7153 - val_loss: 0.7086
# Epoch 95/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7024 - val_loss: 0.7151
# Epoch 96/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7020 - val_loss: 0.7144
# Epoch 97/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7006 - val_loss: 0.7093
# Epoch 98/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6995 - val_loss: 0.7083
# Epoch 99/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.7021 - val_loss: 0.7062
# Epoch 100/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6971 - val_loss: 0.7106
# Epoch 101/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6979target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 655ms/step - loss: 0.6979 - val_loss: 0.7080
# Epoch 102/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6941 - val_loss: 0.7067
# Epoch 103/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6949 - val_loss: 0.7027
# Epoch 104/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6925 - val_loss: 0.7032
# Epoch 105/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6914 - val_loss: 0.7015
# Epoch 106/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6899 - val_loss: 0.7002
# Epoch 107/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6899 - val_loss: 0.6998
# Epoch 108/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6877 - val_loss: 0.6996
# Epoch 109/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6882 - val_loss: 0.6972
# Epoch 110/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6870 - val_loss: 0.6958
# Epoch 111/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6837 - val_loss: 0.6979
# Epoch 112/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6852 - val_loss: 0.6931
# Epoch 113/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6825 - val_loss: 0.6924
# Epoch 114/500
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6811 - val_loss: 0.6910
# Epoch 115/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.6809 - val_loss: 0.6901
# Epoch 116/500
# 1/1 [==============================] - 0s 477ms/step - loss: 0.6809 - val_loss: 0.6884
# Epoch 117/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6776 - val_loss: 0.6893
# Epoch 118/500
# 1/1 [==============================] - 0s 220ms/step - loss: 0.6783 - val_loss: 0.6878
# Epoch 119/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6780 - val_loss: 0.6858
# Epoch 120/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6761 - val_loss: 0.6838
# Epoch 121/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6743target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <তেঁতুলিয়ার ভজনপুর গ্রামে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 668ms/step - loss: 0.6743 - val_loss: 0.6870
# Epoch 122/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6770 - val_loss: 0.6844
# Epoch 123/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6763 - val_loss: 0.6816
# Epoch 124/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6744 - val_loss: 0.6808
# Epoch 125/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6715 - val_loss: 0.6852
# Epoch 126/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6753 - val_loss: 0.6800
# Epoch 127/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6720 - val_loss: 0.6785
# Epoch 128/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6710 - val_loss: 0.6788
# Epoch 129/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6708 - val_loss: 0.6797
# Epoch 130/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6697 - val_loss: 0.6753
# Epoch 131/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6670 - val_loss: 0.6761
# Epoch 132/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6685 - val_loss: 0.6751
# Epoch 133/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6662 - val_loss: 0.6741
# Epoch 134/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6653 - val_loss: 0.6719
# Epoch 135/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6646 - val_loss: 0.6713
# Epoch 136/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6638 - val_loss: 0.6739
# Epoch 137/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6637 - val_loss: 0.6700
# Epoch 138/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.6615 - val_loss: 0.6690
# Epoch 139/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6615 - val_loss: 0.6698
# Epoch 140/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6604 - val_loss: 0.6697
# Epoch 141/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6611target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# 1/1 [==============================] - 1s 656ms/step - loss: 0.6611 - val_loss: 0.6694
# Epoch 142/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6673 - val_loss: 0.6730
# Epoch 143/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6633 - val_loss: 0.6760
# Epoch 144/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6664 - val_loss: 0.6757
# Epoch 145/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6708 - val_loss: 0.6739
# Epoch 146/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6706 - val_loss: 0.6708
# Epoch 147/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6611 - val_loss: 0.6754
# Epoch 148/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6644 - val_loss: 0.6833
# Epoch 149/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6686 - val_loss: 0.6820
# Epoch 150/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6668 - val_loss: 0.6737
# Epoch 151/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6652 - val_loss: 0.6700
# Epoch 152/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6607 - val_loss: 0.6710
# Epoch 153/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6665 - val_loss: 0.6677
# Epoch 154/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6646 - val_loss: 0.6693
# Epoch 155/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6586 - val_loss: 0.6668
# Epoch 156/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6582 - val_loss: 0.6715
# Epoch 157/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6602 - val_loss: 0.6662
# Epoch 158/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6587 - val_loss: 0.6659
# Epoch 159/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6559 - val_loss: 0.6684
# Epoch 160/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6565 - val_loss: 0.6621
# Epoch 161/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6553target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# 1/1 [==============================] - 1s 792ms/step - loss: 0.6553 - val_loss: 0.6605
# Epoch 162/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6552 - val_loss: 0.6621
# Epoch 163/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6532 - val_loss: 0.6616
# Epoch 164/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6517 - val_loss: 0.6610
# Epoch 165/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6534 - val_loss: 0.6595
# Epoch 166/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6513 - val_loss: 0.6603
# Epoch 167/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6509 - val_loss: 0.6590
# Epoch 168/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6503 - val_loss: 0.6565
# Epoch 169/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6499 - val_loss: 0.6577
# Epoch 170/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6496 - val_loss: 0.6577
# Epoch 171/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6476 - val_loss: 0.6570
# Epoch 172/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6486 - val_loss: 0.6558
# Epoch 173/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6471 - val_loss: 0.6556
# Epoch 174/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6471 - val_loss: 0.6564
# Epoch 175/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6469 - val_loss: 0.6563
# Epoch 176/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6462 - val_loss: 0.6548
# Epoch 177/500
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6456 - val_loss: 0.6547
# Epoch 178/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6452 - val_loss: 0.6550
# Epoch 179/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6449 - val_loss: 0.6540
# Epoch 180/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6448 - val_loss: 0.6530
# Epoch 181/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6439target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# 1/1 [==============================] - 1s 664ms/step - loss: 0.6439 - val_loss: 0.6535
# Epoch 182/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6439 - val_loss: 0.6535
# Epoch 183/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6435 - val_loss: 0.6528
# Epoch 184/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6430 - val_loss: 0.6522
# Epoch 185/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6429 - val_loss: 0.6519
# Epoch 186/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6423 - val_loss: 0.6519
# Epoch 187/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6422 - val_loss: 0.6518
# Epoch 188/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6417 - val_loss: 0.6509
# Epoch 189/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6415 - val_loss: 0.6509
# Epoch 190/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6412 - val_loss: 0.6514
# Epoch 191/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6408 - val_loss: 0.6502
# Epoch 192/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6404 - val_loss: 0.6492
# Epoch 193/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6400 - val_loss: 0.6505
# Epoch 194/500
# 1/1 [==============================] - 0s 184ms/step - loss: 0.6397 - val_loss: 0.6488
# Epoch 195/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6392 - val_loss: 0.6486
# Epoch 196/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6388 - val_loss: 0.6483
# Epoch 197/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6383 - val_loss: 0.6479
# Epoch 198/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6378 - val_loss: 0.6471
# Epoch 199/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6375 - val_loss: 0.6469
# Epoch 200/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6375 - val_loss: 0.6481
# Epoch 201/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6388target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 687ms/step - loss: 0.6388 - val_loss: 0.6535
# Epoch 202/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6514 - val_loss: 0.6742
# Epoch 203/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6812 - val_loss: 0.6504
# Epoch 204/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6481 - val_loss: 0.6759
# Epoch 205/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6816 - val_loss: 0.6862
# Epoch 206/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7124 - val_loss: 0.6736
# Epoch 207/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6784 - val_loss: 0.8445
# Epoch 208/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.7992 - val_loss: 0.7879
# Epoch 209/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7412 - val_loss: 0.7580
# Epoch 210/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.7286 - val_loss: 0.7549
# Epoch 211/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7370 - val_loss: 0.7251
# Epoch 212/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7101 - val_loss: 0.7034
# Epoch 213/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6961 - val_loss: 0.6999
# Epoch 214/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7003 - val_loss: 0.6907
# Epoch 215/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6891 - val_loss: 0.6818
# Epoch 216/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6804 - val_loss: 0.6756
# Epoch 217/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6750 - val_loss: 0.6769
# Epoch 218/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6762 - val_loss: 0.6777
# Epoch 219/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6707 - val_loss: 0.6800
# Epoch 220/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6703 - val_loss: 0.6811
# Epoch 221/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6684target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <জবাবদিহিতায় আনার জন্য>
# 1/1 [==============================] - 1s 678ms/step - loss: 0.6684 - val_loss: 0.6788
# Epoch 222/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6672 - val_loss: 0.6719
# Epoch 223/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6627 - val_loss: 0.6705
# Epoch 224/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6627 - val_loss: 0.6668
# Epoch 225/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6602 - val_loss: 0.6650
# Epoch 226/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6591 - val_loss: 0.6631
# Epoch 227/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6561 - val_loss: 0.6635
# Epoch 228/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6562 - val_loss: 0.6615
# Epoch 229/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6539 - val_loss: 0.6599
# Epoch 230/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.6523 - val_loss: 0.6589
# Epoch 231/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6510 - val_loss: 0.6586
# Epoch 232/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6500 - val_loss: 0.6575
# Epoch 233/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6484 - val_loss: 0.6558
# Epoch 234/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6471 - val_loss: 0.6550
# Epoch 235/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6463 - val_loss: 0.6545
# Epoch 236/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6455 - val_loss: 0.6533
# Epoch 237/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6441 - val_loss: 0.6522
# Epoch 238/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6431 - val_loss: 0.6519
# Epoch 239/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6426 - val_loss: 0.6518
# Epoch 240/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6419 - val_loss: 0.6512
# Epoch 241/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6411target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 686ms/step - loss: 0.6411 - val_loss: 0.6504
# Epoch 242/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6404 - val_loss: 0.6497
# Epoch 243/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6400 - val_loss: 0.6489
# Epoch 244/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6392 - val_loss: 0.6483
# Epoch 245/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6386 - val_loss: 0.6479
# Epoch 246/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6382 - val_loss: 0.6473
# Epoch 247/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6377 - val_loss: 0.6466
# Epoch 248/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6371 - val_loss: 0.6462
# Epoch 249/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6366 - val_loss: 0.6458
# Epoch 250/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6363 - val_loss: 0.6454
# Epoch 251/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6359 - val_loss: 0.6450
# Epoch 252/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6354 - val_loss: 0.6446
# Epoch 253/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6351 - val_loss: 0.6443
# Epoch 254/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6348 - val_loss: 0.6441
# Epoch 255/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6344 - val_loss: 0.6438
# Epoch 256/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6340 - val_loss: 0.6436
# Epoch 257/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6338 - val_loss: 0.6433
# Epoch 258/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6335 - val_loss: 0.6430
# Epoch 259/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6332 - val_loss: 0.6427
# Epoch 260/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6329 - val_loss: 0.6424
# Epoch 261/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6327target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 796ms/step - loss: 0.6327 - val_loss: 0.6422
# Epoch 262/500
# 1/1 [==============================] - 0s 234ms/step - loss: 0.6325 - val_loss: 0.6420
# Epoch 263/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6323 - val_loss: 0.6418
# Epoch 264/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6320 - val_loss: 0.6416
# Epoch 265/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6318 - val_loss: 0.6414
# Epoch 266/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6316 - val_loss: 0.6413
# Epoch 267/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6315 - val_loss: 0.6411
# Epoch 268/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6313 - val_loss: 0.6409
# Epoch 269/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6311 - val_loss: 0.6407
# Epoch 270/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6309 - val_loss: 0.6406
# Epoch 271/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6308 - val_loss: 0.6404
# Epoch 272/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6306 - val_loss: 0.6403
# Epoch 273/500
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6305 - val_loss: 0.6401
# Epoch 274/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6303 - val_loss: 0.6400
# Epoch 275/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6302 - val_loss: 0.6399
# Epoch 276/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6300 - val_loss: 0.6397
# Epoch 277/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6299 - val_loss: 0.6396
# Epoch 278/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6298 - val_loss: 0.6395
# Epoch 279/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6297 - val_loss: 0.6394
# Epoch 280/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6295 - val_loss: 0.6392
# Epoch 281/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6294target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 799ms/step - loss: 0.6294 - val_loss: 0.6391
# Epoch 282/500
# 1/1 [==============================] - 0s 221ms/step - loss: 0.6293 - val_loss: 0.6390
# Epoch 283/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6292 - val_loss: 0.6389
# Epoch 284/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6291 - val_loss: 0.6388
# Epoch 285/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6290 - val_loss: 0.6387
# Epoch 286/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6289 - val_loss: 0.6386
# Epoch 287/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6288 - val_loss: 0.6385
# Epoch 288/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6287 - val_loss: 0.6384
# Epoch 289/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6286 - val_loss: 0.6383
# Epoch 290/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6285 - val_loss: 0.6382
# Epoch 291/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6284 - val_loss: 0.6381
# Epoch 292/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6283 - val_loss: 0.6380
# Epoch 293/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6282 - val_loss: 0.6379
# Epoch 294/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6281 - val_loss: 0.6378
# Epoch 295/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6280 - val_loss: 0.6378
# Epoch 296/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6279 - val_loss: 0.6377
# Epoch 297/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6278 - val_loss: 0.6376
# Epoch 298/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6278 - val_loss: 0.6375
# Epoch 299/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6277 - val_loss: 0.6374
# Epoch 300/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6276 - val_loss: 0.6373
# Epoch 301/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6275target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 802ms/step - loss: 0.6275 - val_loss: 0.6373
# Epoch 302/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6274 - val_loss: 0.6372
# Epoch 303/500
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6274 - val_loss: 0.6371
# Epoch 304/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6273 - val_loss: 0.6370
# Epoch 305/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6272 - val_loss: 0.6370
# Epoch 306/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6271 - val_loss: 0.6369
# Epoch 307/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6271 - val_loss: 0.6368
# Epoch 308/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6270 - val_loss: 0.6367
# Epoch 309/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6269 - val_loss: 0.6367
# Epoch 310/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.6269 - val_loss: 0.6366
# Epoch 311/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6268 - val_loss: 0.6365
# Epoch 312/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6267 - val_loss: 0.6365
# Epoch 313/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6267 - val_loss: 0.6364
# Epoch 314/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6266 - val_loss: 0.6363
# Epoch 315/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6265 - val_loss: 0.6363
# Epoch 316/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6265 - val_loss: 0.6362
# Epoch 317/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6264 - val_loss: 0.6361
# Epoch 318/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6263 - val_loss: 0.6361
# Epoch 319/500
# 1/1 [==============================] - 0s 224ms/step - loss: 0.6263 - val_loss: 0.6360
# Epoch 320/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6262 - val_loss: 0.6359
# Epoch 321/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6262target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 797ms/step - loss: 0.6262 - val_loss: 0.6359
# Epoch 322/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6261 - val_loss: 0.6358
# Epoch 323/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6260 - val_loss: 0.6358
# Epoch 324/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6260 - val_loss: 0.6357
# Epoch 325/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6259 - val_loss: 0.6357
# Epoch 326/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6259 - val_loss: 0.6356
# Epoch 327/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6258 - val_loss: 0.6355
# Epoch 328/500
# 1/1 [==============================] - 0s 219ms/step - loss: 0.6257 - val_loss: 0.6355
# Epoch 329/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6257 - val_loss: 0.6354
# Epoch 330/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6256 - val_loss: 0.6354
# Epoch 331/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6256 - val_loss: 0.6353
# Epoch 332/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6255 - val_loss: 0.6353
# Epoch 333/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6255 - val_loss: 0.6352
# Epoch 334/500
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6254 - val_loss: 0.6352
# Epoch 335/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6254 - val_loss: 0.6351
# Epoch 336/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6253 - val_loss: 0.6351
# Epoch 337/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6253 - val_loss: 0.6350
# Epoch 338/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.6252 - val_loss: 0.6350
# Epoch 339/500
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6252 - val_loss: 0.6349
# Epoch 340/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6251 - val_loss: 0.6349
# Epoch 341/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6251target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 792ms/step - loss: 0.6251 - val_loss: 0.6348
# Epoch 342/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6250 - val_loss: 0.6348
# Epoch 343/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6250 - val_loss: 0.6347
# Epoch 344/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6249 - val_loss: 0.6347
# Epoch 345/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6249 - val_loss: 0.6346
# Epoch 346/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6248 - val_loss: 0.6346
# Epoch 347/500
# 1/1 [==============================] - 0s 186ms/step - loss: 0.6248 - val_loss: 0.6345
# Epoch 348/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6247 - val_loss: 0.6345
# Epoch 349/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6247 - val_loss: 0.6344
# Epoch 350/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6247 - val_loss: 0.6344
# Epoch 351/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6246 - val_loss: 0.6343
# Epoch 352/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6246 - val_loss: 0.6343
# Epoch 353/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6245 - val_loss: 0.6342
# Epoch 354/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6245 - val_loss: 0.6342
# Epoch 355/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6244 - val_loss: 0.6342
# Epoch 356/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6244 - val_loss: 0.6341
# Epoch 357/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6243 - val_loss: 0.6341
# Epoch 358/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6243 - val_loss: 0.6340
# Epoch 359/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6243 - val_loss: 0.6340
# Epoch 360/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6242 - val_loss: 0.6340
# Epoch 361/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6242target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 794ms/step - loss: 0.6242 - val_loss: 0.6339
# Epoch 362/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6241 - val_loss: 0.6339
# Epoch 363/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6241 - val_loss: 0.6338
# Epoch 364/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6241 - val_loss: 0.6338
# Epoch 365/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6240 - val_loss: 0.6337
# Epoch 366/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6240 - val_loss: 0.6337
# Epoch 367/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6239 - val_loss: 0.6337
# Epoch 368/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6239 - val_loss: 0.6336
# Epoch 369/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6239 - val_loss: 0.6336
# Epoch 370/500
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6238 - val_loss: 0.6336
# Epoch 371/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6238 - val_loss: 0.6335
# Epoch 372/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6238 - val_loss: 0.6335
# Epoch 373/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6237 - val_loss: 0.6334
# Epoch 374/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6237 - val_loss: 0.6334
# Epoch 375/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6236 - val_loss: 0.6334
# Epoch 376/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6236 - val_loss: 0.6333
# Epoch 377/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6236 - val_loss: 0.6333
# Epoch 378/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6235 - val_loss: 0.6333
# Epoch 379/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6235 - val_loss: 0.6332
# Epoch 380/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6235 - val_loss: 0.6332
# Epoch 381/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6234target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# 1/1 [==============================] - 1s 802ms/step - loss: 0.6234 - val_loss: 0.6332
# Epoch 382/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6234 - val_loss: 0.6331
# Epoch 383/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6234 - val_loss: 0.6331
# Epoch 384/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6233 - val_loss: 0.6330
# Epoch 385/500
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6233 - val_loss: 0.6330
# Epoch 386/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6232 - val_loss: 0.6330
# Epoch 387/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6232 - val_loss: 0.6329
# Epoch 388/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6232 - val_loss: 0.6329
# Epoch 389/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6231 - val_loss: 0.6329
# Epoch 390/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6231 - val_loss: 0.6328
# Epoch 391/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6231 - val_loss: 0.6328
# Epoch 392/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6230 - val_loss: 0.6328
# Epoch 393/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6230 - val_loss: 0.6327
# Epoch 394/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6230 - val_loss: 0.6327
# Epoch 395/500
# 1/1 [==============================] - 1s 527ms/step - loss: 0.6229 - val_loss: 0.6327
# Epoch 396/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6229 - val_loss: 0.6326
# Epoch 397/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6229 - val_loss: 0.6326
# Epoch 398/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6229 - val_loss: 0.6326
# Epoch 399/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6228 - val_loss: 0.6326
# Epoch 400/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6228 - val_loss: 0.6325
# Epoch 401/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6228target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 818ms/step - loss: 0.6228 - val_loss: 0.6325
# Epoch 402/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6227 - val_loss: 0.6325
# Epoch 403/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6227 - val_loss: 0.6324
# Epoch 404/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6227 - val_loss: 0.6324
# Epoch 405/500
# 1/1 [==============================] - 0s 235ms/step - loss: 0.6226 - val_loss: 0.6324
# Epoch 406/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6226 - val_loss: 0.6323
# Epoch 407/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6226 - val_loss: 0.6323
# Epoch 408/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6226 - val_loss: 0.6323
# Epoch 409/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6225 - val_loss: 0.6322
# Epoch 410/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6225 - val_loss: 0.6322
# Epoch 411/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6225 - val_loss: 0.6322
# Epoch 412/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6224 - val_loss: 0.6322
# Epoch 413/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6224 - val_loss: 0.6321
# Epoch 414/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6224 - val_loss: 0.6321
# Epoch 415/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6223 - val_loss: 0.6321
# Epoch 416/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6223 - val_loss: 0.6320
# Epoch 417/500
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6223 - val_loss: 0.6320
# Epoch 418/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6223 - val_loss: 0.6320
# Epoch 419/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6222 - val_loss: 0.6320
# Epoch 420/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6222 - val_loss: 0.6319
# Epoch 421/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6222target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# 1/1 [==============================] - 1s 818ms/step - loss: 0.6222 - val_loss: 0.6319
# Epoch 422/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6222 - val_loss: 0.6319
# Epoch 423/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6221 - val_loss: 0.6319
# Epoch 424/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6221 - val_loss: 0.6318
# Epoch 425/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6221 - val_loss: 0.6318
# Epoch 426/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6220 - val_loss: 0.6318
# Epoch 427/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6220 - val_loss: 0.6317
# Epoch 428/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6220 - val_loss: 0.6317
# Epoch 429/500
# 1/1 [==============================] - 0s 212ms/step - loss: 0.6220 - val_loss: 0.6317
# Epoch 430/500
# 1/1 [==============================] - 0s 192ms/step - loss: 0.6219 - val_loss: 0.6317
# Epoch 431/500
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6219 - val_loss: 0.6316
# Epoch 432/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6219 - val_loss: 0.6316
# Epoch 433/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6219 - val_loss: 0.6316
# Epoch 434/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6218 - val_loss: 0.6316
# Epoch 435/500
# 1/1 [==============================] - 0s 190ms/step - loss: 0.6218 - val_loss: 0.6315
# Epoch 436/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6218 - val_loss: 0.6315
# Epoch 437/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.6218 - val_loss: 0.6315
# Epoch 438/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6217 - val_loss: 0.6315
# Epoch 439/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6217 - val_loss: 0.6314
# Epoch 440/500
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6217 - val_loss: 0.6314
# Epoch 441/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6217target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# 1/1 [==============================] - 1s 806ms/step - loss: 0.6217 - val_loss: 0.6314
# Epoch 442/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.6216 - val_loss: 0.6314
# Epoch 443/500
# 1/1 [==============================] - 0s 215ms/step - loss: 0.6216 - val_loss: 0.6313
# Epoch 444/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6216 - val_loss: 0.6313
# Epoch 445/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6216 - val_loss: 0.6313
# Epoch 446/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6216 - val_loss: 0.6313
# Epoch 447/500
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6215 - val_loss: 0.6313
# Epoch 448/500
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6215 - val_loss: 0.6312
# Epoch 449/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6215 - val_loss: 0.6312
# Epoch 450/500
# 1/1 [==============================] - 0s 188ms/step - loss: 0.6215 - val_loss: 0.6312
# Epoch 451/500
# 1/1 [==============================] - 0s 214ms/step - loss: 0.6214 - val_loss: 0.6312
# Epoch 452/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6214 - val_loss: 0.6311
# Epoch 453/500
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6214 - val_loss: 0.6311
# Epoch 454/500
# 1/1 [==============================] - 0s 205ms/step - loss: 0.6214 - val_loss: 0.6311
# Epoch 455/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6213 - val_loss: 0.6311
# Epoch 456/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6213 - val_loss: 0.6310
# Epoch 457/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6213 - val_loss: 0.6310
# Epoch 458/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6213 - val_loss: 0.6310
# Epoch 459/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6213 - val_loss: 0.6310
# Epoch 460/500
# 1/1 [==============================] - 0s 184ms/step - loss: 0.6212 - val_loss: 0.6310
# Epoch 461/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6212target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# 1/1 [==============================] - 1s 819ms/step - loss: 0.6212 - val_loss: 0.6309
# Epoch 462/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6212 - val_loss: 0.6309
# Epoch 463/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6212 - val_loss: 0.6309
# Epoch 464/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6212 - val_loss: 0.6309
# Epoch 465/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6211 - val_loss: 0.6309
# Epoch 466/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6211 - val_loss: 0.6308
# Epoch 467/500
# 1/1 [==============================] - 0s 213ms/step - loss: 0.6211 - val_loss: 0.6308
# Epoch 468/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6211 - val_loss: 0.6308
# Epoch 469/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6210 - val_loss: 0.6308
# Epoch 470/500
# 1/1 [==============================] - 0s 199ms/step - loss: 0.6210 - val_loss: 0.6308
# Epoch 471/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6210 - val_loss: 0.6307
# Epoch 472/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6210 - val_loss: 0.6307
# Epoch 473/500
# 1/1 [==============================] - 0s 217ms/step - loss: 0.6210 - val_loss: 0.6307
# Epoch 474/500
# 1/1 [==============================] - 0s 195ms/step - loss: 0.6209 - val_loss: 0.6307
# Epoch 475/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6209 - val_loss: 0.6306
# Epoch 476/500
# 1/1 [==============================] - 0s 198ms/step - loss: 0.6209 - val_loss: 0.6306
# Epoch 477/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6209 - val_loss: 0.6306
# Epoch 478/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6209 - val_loss: 0.6306
# Epoch 479/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6208 - val_loss: 0.6306
# Epoch 480/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6208 - val_loss: 0.6305
# Epoch 481/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6208target:     <শিশু শ্রমিক রয়েছে দেশটিতে>
# prediction: <শিশু শ্রমিক রয়েছে দেশটিতে>
# target:     <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# prediction: <সবচেয়ে দরিদ্র এলাকা গুলোর এক>
# target:     <চাঁদনী রাতের ভালোবাসার ফটো>
# prediction: <চাঁদনী রাতের ভালোবাসার ফটো>
# target:     <আকাশের দিকেই ছুড়তে থাকে>
# prediction: <আকাশের দিকেই ছুড়তে থাকে>
# target:     <এক শূন্য গোলে পরাজিত করে>
# prediction: <এক শূন্য গোলে পরাজিত করে>
# 1/1 [==============================] - 1s 829ms/step - loss: 0.6208 - val_loss: 0.6305
# Epoch 482/500
# 1/1 [==============================] - 0s 201ms/step - loss: 0.6208 - val_loss: 0.6305
# Epoch 483/500
# 1/1 [==============================] - 0s 189ms/step - loss: 0.6208 - val_loss: 0.6305
# Epoch 484/500
# 1/1 [==============================] - 0s 203ms/step - loss: 0.6207 - val_loss: 0.6305
# Epoch 485/500
# 1/1 [==============================] - 0s 202ms/step - loss: 0.6207 - val_loss: 0.6305
# Epoch 486/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6207 - val_loss: 0.6304
# Epoch 487/500
# 1/1 [==============================] - 0s 210ms/step - loss: 0.6207 - val_loss: 0.6304
# Epoch 488/500
# 1/1 [==============================] - 0s 204ms/step - loss: 0.6207 - val_loss: 0.6304
# Epoch 489/500
# 1/1 [==============================] - 0s 206ms/step - loss: 0.6207 - val_loss: 0.6304
# Epoch 490/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6206 - val_loss: 0.6304
# Epoch 491/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6206 - val_loss: 0.6303
# Epoch 492/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.6206 - val_loss: 0.6303
# Epoch 493/500
# 1/1 [==============================] - 0s 209ms/step - loss: 0.6206 - val_loss: 0.6303
# Epoch 494/500
# 1/1 [==============================] - 0s 200ms/step - loss: 0.6206 - val_loss: 0.6303
# Epoch 495/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6205 - val_loss: 0.6303
# Epoch 496/500
# 1/1 [==============================] - 0s 196ms/step - loss: 0.6205 - val_loss: 0.6302
# Epoch 497/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.6205 - val_loss: 0.6302
# Epoch 498/500
# 1/1 [==============================] - 0s 194ms/step - loss: 0.6205 - val_loss: 0.6302
# Epoch 499/500
# 1/1 [==============================] - 0s 208ms/step - loss: 0.6205 - val_loss: 0.6302
# Epoch 500/500
# 1/1 [==============================] - 0s 211ms/step - loss: 0.6205 - val_loss: 0.6302

# %% [markdown]
# ### **Seeker's Test**

# %%
import os
import sys
import pandas as pd
from IPython import display as ipd

import tensorflow as tf

tf.__version__
# Out:
# '2.9.2'

# %%
# !mkdir test-samples/test_wav/
# Out:
# mkdir: cannot create directory ‘test-samples/test_wav/’: File exists

# %%
# test audio sample
test_data = '/content/test-samples/test_data.csv'

df = pd.read_csv(test_data)
print(df)
# Out:
#                      audio                            text
# 0  test_wav/0750033e3e.wav  সবচেয়ে দরিদ্র এলাকাগুলোর একটি

# %%
# read sample audio and play it
wav_dir = '/content/test-samples/'
for i, d in df.iterrows():
    audio, text = os.path.join(wav_dir, d['audio']), d['text']
    print(f"text: {text}")
    ipd.display(ipd.Audio(audio))
# Out:
# text: সবচেয়ে দরিদ্র এলাকাগুলোর একটি
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# read character sets
chars_db_path = '/content/test-samples/chars_75.csv'

unique_chars = pd.read_csv(chars_db_path, skip_blank_lines=False)['chars']
unique_chars = unique_chars.to_list()

print(f"Total {len(unique_chars)} chars: {unique_chars}")
# Out:
# Total 71 chars: [' ', '।', 'ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঋ', 'এ', 'ঐ', 'ও', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ড়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']

# %%
# add bnasr to sys path
sys.path.append(os.path.abspath('/content/'))

# %%
max_target_len = 30
vectorizer = VectorizeChar(max_target_len)
print("vocab size", len(vectorizer.get_vocabulary()))
# Out:
# vocab size 75

# %%
# set checkpoint path
model_checkpoint = '/content/'

# load checkpoint
latest = tf.train.latest_checkpoint(model_checkpoint)
model.load_weights(latest)

# %%
def predict(source, target_start_token_idx, target_maxlen):
        """Performs inference over one batch of inputs using greedy decoding."""
        bs = tf.shape(source)[0]
        enc = model.encoder(source)
        dec_input = tf.ones((bs, 1), dtype=tf.int32) * target_start_token_idx
        dec_logits = []
        for i in range(target_maxlen-1):
            dec_out = model.decode(enc, dec_input)
            logits = model.classifier(dec_out)
            logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
            last_logit = tf.expand_dims(logits[:, -1], axis=-1)
            dec_logits.append(last_logit)
            dec_input = tf.concat([dec_input, last_logit], axis=-1)
        return dec_input

# %%
target_start_token_idx=2
target_end_token_idx = 3
idx_to_char = vectorizer.get_vocabulary()

for i, d in df.iterrows():
    # take audio and it's actual text
    audio, text = os.path.join(wav_dir, d['audio']), d['text']
    print(f"Sample [ {i+1} ] target text: {text}")
    print(f"Target audio: {audio}")
    ipd.display(ipd.Audio(audio))
    
    target_audio = path_to_audio(audio)
    target_audio = tf.expand_dims(target_audio, 0)
    # perform prediction on given target audio file
    preds = predict(target_audio, target_start_token_idx, target_maxlen=max_target_len)
    
    preds = preds.numpy()[0]
    prediction = []
    for idx in preds:
        prediction.append(idx_to_char[idx])
        if idx == target_end_token_idx:
            break
    
    prediction = ''.join(prediction)
    print(f"prediction: {prediction}")
    print('-'*50)
# Out:
# Sample [ 1 ] target text: সবচেয়ে দরিদ্র এলাকাগুলোর একটি
# Target audio: /content/test-samples/test_wav/0750033e3e.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# prediction: <ডঙঈনভন কঝতকফঝ অঞণআণ ইদঞপঝ অআ>
# --------------------------------------------------

# %%
print(prediction)
# Out:
# <টতটদ টফঝছতআ ঝভনউন কনটএতঐন>
